# %%
# %matplotlib inline
import numpy as np
import pickle
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import glob

# %%
with open('codings/mu.pkl','rb') as f: mu = pickle.load(f)
with open('codings/sigma.pkl','rb') as f: sigma = pickle.load(f)

# %%
zs_path_list = ['new_zs/new_zs_'+str(i)+'.npy' for i in range(200)]

# %%
zs_path_list
# Out:
# ['new_zs/new_zs_0.npy',
#  'new_zs/new_zs_1.npy',
#  'new_zs/new_zs_2.npy',
#  'new_zs/new_zs_3.npy',
#  'new_zs/new_zs_4.npy',
#  'new_zs/new_zs_5.npy',
#  'new_zs/new_zs_6.npy',
#  'new_zs/new_zs_7.npy',
#  'new_zs/new_zs_8.npy',
#  'new_zs/new_zs_9.npy',
#  'new_zs/new_zs_10.npy',
#  'new_zs/new_zs_11.npy',
#  'new_zs/new_zs_12.npy',
#  'new_zs/new_zs_13.npy',
#  'new_zs/new_zs_14.npy',
#  'new_zs/new_zs_15.npy',
#  'new_zs/new_zs_16.npy',
#  'new_zs/new_zs_17.npy',
#  'new_zs/new_zs_18.npy',
#  'new_zs/new_zs_19.npy',
#  'new_zs/new_zs_20.npy',
#  'new_zs/new_zs_21.npy',
#  'new_zs/new_zs_22.npy',
#  'new_zs/new_zs_23.npy',
#  'new_zs/new_zs_24.npy',
#  'new_zs/new_zs_25.npy',
#  'new_zs/new_zs_26.npy',
#  'new_zs/new_zs_27.npy',
#  'new_zs/new_zs_28.npy',
#  'new_zs/new_zs_29.npy',
#  'new_zs/new_zs_30.npy',
#  'new_zs/new_zs_31.npy',
#  'new_zs/new_zs_32.npy',
#  'new_zs/new_zs_33.npy',
#  'new_zs/new_zs_34.npy',
#  'new_zs/new_zs_35.npy',
#  'new_zs/new_zs_36.npy',
# ...

# %%
mu
# Out:
# array([[ 3.6505140e-02, -1.0666554e+00,  2.1532703e-02, ...,
#          3.0580284e-03, -7.8979230e-01, -2.1902520e-02],
#        [ 2.1361206e-02, -1.3340920e+00,  1.1557755e-02, ...,
#         -2.9257885e-03,  4.9469447e-01, -1.5704600e-02],
#        [ 2.6199017e-02, -2.1068099e+00,  6.5587647e-03, ...,
#         -9.8375371e-03, -1.3885963e-01, -2.1768559e-02],
#        ...,
#        [ 1.8154461e-02, -8.3777708e-01,  1.1361597e-02, ...,
#         -1.0067818e-03,  5.5379820e-01, -1.4092140e-02],
#        [ 3.0991446e-02,  3.7606877e-01,  1.9604009e-02, ...,
#          2.6762034e-03, -4.2218232e-01, -1.5014293e-02],
#        [ 1.1818079e-02,  8.5871017e-01,  8.8359080e-03, ...,
#          6.2928256e-04,  4.7582734e-01, -9.6158106e-03]], dtype=float32)

# %%
mu.max()
# Out:
# 3.888314

# %%
zs_list = []
for path in zs_path_list:
    zs_list.append(np.load(path))

# %%
zs.max()
# Out:
# 3.888314

# %%
pca = PCA(n_components=2)
pca.fit(mu)
pca_mu = pca.transform(mu)

# %%
for x in zs_list:
    pca_zs = pca.transform(x)
    plt.scatter(pca_zs[:,0], pca_zs[:,1],c = 'r',label='New')
    plt.scatter(pca_mu[:,0], pca_mu[:,1],c = 'b',label='Old')
    plt.legend()
    plt.show()
